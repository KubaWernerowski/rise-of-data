# %%
import pysentiment as ps
import nltk
from spacy.lang.en import English
# importing list of stop words
import spacy
spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS
import time

nlp = English()

# %%
# gets rid of stop words and returns a string
def stop_words(text):
    doc = nlp(text)
    filtered_sent = []
    # filtering stop words
    for word in doc:
        if word.is_stop==False:
            filtered_sent.append(str(word))
    filtered_sent = ' '.join(filtered_sent)
    return filtered_sent

# %%
# Sentiment analyzer
lm = ps.LM()

# %% [markdown]
# <h1> Working with JSON files

# %%
#Imports
import pandas as pd
import numpy as np
import glob
import re
import pickle
from datetime import datetime


# Load all company transcripts
all_transcripts = glob.glob("data/company_transcripts/*")
df = [pd.read_json(f) for f in all_transcripts]

# Pre-processing functions


def get_quarter(title):
    quarter_reg_expr = "([A-Za-z]+[\d@]+[\w@]*|[\d@]+[A-Za-z]+[\w@]*)"
    words = re.findall(quarter_reg_expr, title)

    def has_numbers(inputString):
        return any(char.isdigit() for char in inputString)

    for word in words:
        if "q" in word.lower() and has_numbers(word):
            return word
            # Handle Q1 vs 1Q case
            if len(word) == 2:
                if word[0] in "1234":
                    return word[1] + word[0]
                else:
                    return word
            # Handle case with F
            elif word[0] == "F":
                return word[2] + word[1]
    return None


def get_ticker(row, _id):
    title = row['title'][_id]
    body = ' '.join(row['body'][_id])

    try:
        # Try to get ticker from title
        open_paren = title.index("(")
        close_paren = title.index(")")
        return title[open_paren+1:close_paren]

    except:
        # find ticker in body
        colon = body.index(":")
        close_paren = body.index(")")
        return body[colon+1:close_paren]


# Clean
rows_list = []

for row in df:
    ids = list(row['title'].keys())

    for _id in ids:
        title = row['title'][_id]
        full_date = row['date'][_id]

        ticker = get_ticker(row, _id)
        quarter = get_quarter(title)
        date = full_date.date().strftime("%Y-%m-%d")
        time = full_date.time().strftime("%H:%M")
        body = ' '.join(row['body'][_id])

        # There are 10 titles without an explicit quarter
        if quarter is None:
            quarter = "FILL ME IN"

        new_row = [ticker, quarter, date, time, body]

        rows_list.append(new_row)

df_transcripts = pd.DataFrame(
    rows_list, columns=["ticker", "quarter", "date", "time", "body"])


with open("transcripts.p", "wb") as f:
    pickle.dump(df_transcripts, f)

# %%
# creating new instance of JSON dataframe
new = df_transcripts
# Out:
#       ticker quarter        date   time  \
# 0          T      Q1  2019-04-24  08:30
# 1          T      Q4  2018-01-31  16:30
# 2          T      Q3  2016-10-24  08:30
# 3          T      Q2  2015-07-23  16:30
# 4          T      Q3  2015-10-22  16:30
# 5          T      Q3  2014-10-22  16:30
# 6          T      Q4  2015-01-27  16:30
# 7          T      Q3  2013-10-23  16:30
# 8          T      Q4  2014-01-28  16:30
# 9          T      Q2  2013-07-23  16:30
# 10         T      Q1  2014-04-22  16:30
# 11         T      Q2  2014-07-23  16:30
# 12         T      Q1  2015-04-22  16:30
# 13         T      Q4  2016-01-27  16:30
# 14         T      Q1  2016-04-26  16:30
# 15         T      Q2  2016-07-21  16:30
# 16         T      Q1  2017-04-26  16:30
# 17         T      Q2  2017-07-25  16:30
# 18         T      Q1  2018-04-25  16:30
# 19         T      Q2  2018-07-25  16:30
Wells Fargo & Company (NYSE:WFC) Q3 2019 Earni...
# 12376  Wells Fargo & Company (NYSE:WFC) Q4 2019 Resul...
# 12377  Wells Fargo & Co. (NYSE:WFC) Q2 2014 Earnings ...
# 12378  Wells Fargo & Company (NYSE:WFC) Q3 2014 Resul...
#
# [12379 rows x 5 columns]

# %%
# Add new columns to df
new["sentiment"] = ""
new["positive"] = ""
new["negative"] = ""
new["subjectivity"] = ""

# %%
import time
t0 = time.time()

for i in range(new.shape[0]):
    text = new['body'][i]
    text_no_stop_words = stop_words(text)
    
    tokens = lm.tokenize(text_no_stop_words)
    score = lm.get_score(tokens)
    
    new["sentiment"][i] = score['Polarity']
    new["positive"][i] = score["Positive"]
    new["negative"][i] = score["Negative"]
    new["subjectivity"][i] = score["Subjectivity"]

time.time() - t0
# Out:
# 1551.0550129413605

# %%
new
# Out:
#       ticker quarter        date   time  \
# 0          T      Q1  2019-04-24  08:30
# 1          T      Q4  2018-01-31  16:30
# 2          T      Q3  2016-10-24  08:30
# 3          T      Q2  2015-07-23  16:30
# 4          T      Q3  2015-10-22  16:30
# 5          T      Q3  2014-10-22  16:30
# 6          T      Q4  2015-01-27  16:30
# 7          T      Q3  2013-10-23  16:30
# 8          T      Q4  2014-01-28  16:30
# 9          T      Q2  2013-07-23  16:30
# 10         T      Q1  2014-04-22  16:30
# 11         T      Q2  2014-07-23  16:30
# 12         T      Q1  2015-04-22  16:30
# 13         T      Q4  2016-01-27  16:30
# 14         T      Q1  2016-04-26  16:30
# 15         T      Q2  2016-07-21  16:30
# 16         T      Q1  2017-04-26  16:30
# 17         T      Q2  2017-07-25  16:30
# 18         T      Q1  2018-04-25  16:30
# 19         T      Q2  2018-07-25  16:30
# 20         T      Q3  2018-10-24  08:30
# 21         T      Q4  2020-01-29  08:30
# 22         T      Q3  2019-10-28  08:30
# 23         T      Q2  2019-07-24  08:30
# 24         T      Q1  2013-04-23  16:30
# 25         T      Q4  2013-01-24  04:30
# 26         T      Q4  2012-01-26  10:00
# 27         T      Q1  2012-04-24  10:00
# 28         T      Q2  2012-07-24  09:30
# 29       PHM      Q4  2012-02-02  08:30
# ...      ...     ...         ...    ...
# 12349    AOS      Q2  2019-07-30  10:00
# 12350    AOS      Q3  2019-10-29  10:00
# 12351    AOS      Q4  2020-01-28  10:00
# 12352    WFC      Q4  2015-01-15  10:00
# 12353    WFC      Q1  2015-04-14  10:00
# 12354    WFC      Q2  2015-07-14  10:00
# 12355    WFC      Q3  2015-10-14  10:00
# 12356    WFC      Q1  2016-04-14  10:00
# 12357    WFC      Q4  2012-01-17  09:30
# 12358    WFC      Q1  2012-04-13  10:00
# 12359    WFC      Q2  2012-07-13  10:00
# 12360    WFC      Q3  2012-10-12  10:00
# 12361    WFC      Q4  2013-01-11  10:00
# 12362    WFC      Q1  2013-04-12  10:00
# 12363    WFC      Q2  2013-07-12  10:00
# 12364    WFC      Q4  2014-01-14  10:00
# 12365    WFC      Q1  2014-04-11  10:00
# 12366    WFC      Q3  2016-10-14  10:00
# 12367    WFC      Q4  2017-01-13  11:30
# 12368    WFC      Q3  2017-10-13  10:00
# 12369    WFC      Q4  2018-01-12  10:00
# 10          55    0.0726221
# 11          62    0.0692547
# 12          66    0.0670645
# 13          90    0.0759459
# 14          64    0.0822006
# 15          56    0.0714691
# 16          93    0.0633448
# 17          81    0.0730594
# 18          55    0.0653576
# 19         134    0.0759916
# 20          74    0.0658436
# 21          83    0.0776887
# 22          75    0.0661092
# 23          85    0.0677462
# 24          90    0.0768728
# 25          72    0.0666454
# 26          77    0.0612128
# 27          49    0.0610881
# 28          61    0.0704023
# 29         121    0.0814051
# ...        ...          ...
# 12349      104    0.0795781
# 12350       75    0.0668896
# 12351      119    0.0819985
# 12352      137    0.0734793
# 12353       99    0.0668203
# 12354      159    0.0766885
# 12355      111    0.0723666
# 12356      185    0.0736932
# 12357      175    0.0867126
# 12358      169    0.0815568
# 12359      127     0.084326
# 12360      179     0.075361
# 12361      231     0.081223
# 12362      189    0.0921627
# 12363      205    0.0877543
# 12364      166    0.0889842
# 12365      180    0.0879588
# 12366      226    0.0762846
# 12367      197    0.0854395
# 12368      214    0.0769984
# 12369      152    0.0800582
# 12370      199    0.0806936
# 12371      222    0.0809743
# 12372      193    0.0749365
# 12373      218    0.0799416
# 12374      162    0.0745739
# 12375      159    0.0770823
# 12376      147    0.0783913
# 12377      183    0.0778643
# 12378      148    0.0743064
#
# [12379 rows x 9 columns]

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

adj_closed_df = pd.read_csv('data/adj_close.csv')

new = new.astype({'positive': np.float64, 'negative': np.float64, 'sentiment': np.float64})


adj_closed_df.head(10)
# Out:
#   Ticker symbol       Date  Close   Returns
# 0           AAL   1/3/2012   5.12  0.000000
# 1           AAL   1/4/2012   5.03 -0.017578
# 2           AAL   1/5/2012   5.47  0.087475
# 3           AAL   1/6/2012   5.60  0.023766
# 4           AAL   1/9/2012   5.72  0.021429
# 5           AAL  1/10/2012   5.72  0.000000
# 6           AAL  1/11/2012   5.91  0.033217
# 7           AAL  1/12/2012   6.05  0.023689
# 8           AAL  1/13/2012   5.97 -0.013223
# 9           AAL  1/17/2012   5.88 -0.015075

# %%
# setting new instances of new and adj_closed.df
sentiment = new
stocks = adj_closed_df

# %%
sentiment['date'] = pd.to_datetime(sentiment['date'])
stocks['Date'] = pd.to_datetime(stocks['Date'])

# %%
# sentiment_df = sentiment.set_index('date')
# # stocks_df = stocks.set_index("Date")
stocks_df = stocks
stocks_df.reset_index()
# Out:
#          index Ticker symbol       Date       Close   Returns
# 0            0           AAL 2012-01-03    5.120000  0.000000
# 1            1           AAL 2012-01-04    5.030000 -0.017578
# 2            2           AAL 2012-01-05    5.470000  0.087475
# 3            3           AAL 2012-01-06    5.600000  0.023766
# 4            4           AAL 2012-01-09    5.720000  0.021429
# 5            5           AAL 2012-01-10    5.720000  0.000000
# 6            6           AAL 2012-01-11    5.910000  0.033217
# 7            7           AAL 2012-01-12    6.050000  0.023689
# 8            8           AAL 2012-01-13    5.970000 -0.013223
# 9            9           AAL 2012-01-17    5.880000 -0.015075
# 10          10           AAL 2012-01-18    6.040000  0.027211
# 11          11           AAL 2012-01-19    6.260000  0.036424
# 12          12           AAL 2012-01-20    6.370000  0.017572
# 13          13           AAL 2012-01-23    6.260000 -0.017268
# 14          14           AAL 2012-01-24    6.410000  0.023962
# 15          15           AAL 2012-01-25    7.520000  0.173167
# 16          16           AAL 2012-01-26    7.850000  0.043883
# 17          17           AAL 2012-01-27    8.180000  0.042038
# 18          18           AAL 2012-01-30    8.520000  0.041565
# 19          19           AAL 2012-01-31    8.440000 -0.009390
# 20          20           AAL 2012-02-01    8.900000  0.054502
# 21          21           AAL 2012-02-02    9.120000  0.024719
# 22          22           AAL 2012-02-03    9.640000  0.057018
# 23          23           AAL 2012-02-06    9.150000 -0.050830
# 24          24           AAL 2012-02-07    9.240000  0.009836
# 25          25           AAL 2012-02-08    9.100000 -0.015151
# 26          26           AAL 2012-02-09    8.960000 -0.015385
# 27          27           AAL 2012-02-10    8.850000 -0.012277
# 28          28           AAL 2012-02-13    9.180000  0.037288
# 29          29           AAL 2012-02-14    9.000000 -0.019608
# ...        ...           ...        ...         ...       ...
# 917625  917625           ZTS 2019-12-18  126.989998 -0.000865
# 917626  917626           ZTS 2019-12-19  128.740005  0.013781
# 917627  917627           ZTS 2019-12-20  132.679993  0.030604
# 917628  917628           ZTS 2019-12-23  132.369995 -0.002336
# 917629  917629           ZTS 2019-12-24  132.919998  0.004155
# 917630  917630           ZTS 2019-12-26  133.029999  0.000828
# 917631  917631           ZTS 2019-12-27  133.250000  0.001654
# 917632  917632           ZTS 2019-12-30  132.210007 -0.007805
# 917633  917633           ZTS 2019-12-31  132.350006  0.001059
# 917634  917634           ZTS 2020-01-02  134.139999  0.013525
# 917635  917635           ZTS 2020-01-03  134.160004  0.000149
# 917636  917636           ZTS 2020-01-06  133.130005 -0.007677
# 917637  917637           ZTS 2020-01-07  133.580002  0.003380
# 917638  917638           ZTS 2020-01-08  133.289993 -0.002171
# 917639  917639           ZTS 2020-01-09  135.059998  0.013279
# 917640  917640           ZTS 2020-01-10  135.570007  0.003776
# 917641  917641           ZTS 2020-01-13  136.509995  0.006934
# 917642  917642           ZTS 2020-01-14  137.270004  0.005567
# 917643  917643           ZTS 2020-01-15  138.539993  0.009252
# 917644  917644           ZTS 2020-01-16  139.240005  0.005053
# 917645  917645           ZTS 2020-01-17  140.160004  0.006607
# 917646  917646           ZTS 2020-01-21  141.929993  0.012628
# 917647  917647           ZTS 2020-01-22  141.500000 -0.003030
# 917648  917648           ZTS 2020-01-23  138.339996 -0.022332
# 917649  917649           ZTS 2020-01-24  136.309998 -0.014674
# 917650  917650           ZTS 2020-01-27  135.960007 -0.002568
# 917651  917651           ZTS 2020-01-28  138.259995  0.016917
# 917652  917652           ZTS 2020-01-29  138.509995  0.001808
# 917653  917653           ZTS 2020-01-30  138.029999 -0.003465
# 917654  917654           ZTS 2020-01-31  134.210007 -0.027675
#
# [917655 rows x 5 columns]

# %%
data = pd.DataFrame(columns=["ticker", "quarter", "date", "sentiment", "returns"])

# %%
companies = pd.read_csv("data/companies.csv")
# Out:
# 399    Telecommunication Services
# Name: GICS Sector, dtype: object

# %%
all_rows = []

t0 = time.time()
for row in sentiment_df.iterrows():
    date = row[0]
    ticker = row[1]['ticker']
    quarter = row[1]['quarter']
    sentiment = row[1]['sentiment']
    subjectivity = row[1]['subjectivity']
    pos = row[1]['positive']
    neg = row[1]['negative']
    
    pos_neg_ratio = pos / neg

    company = companies[companies['Ticker symbol'] == ticker]
    
    sector = company['GICS Sector']
    sub_industry = company['GICS Sub Industry']
    
    try:
        idx_to_get = stocks_df[(stocks_df['Ticker symbol'] == ticker) & (stocks_df["Date"] == date)].index[0] + 1
    except: 
        continue

    returns = stocks_df.loc[idx_to_get, ]['Returns']

    new_row = [ticker, quarter, date, sentiment, subjectivity, pos_neg_ratio, sector, sub_industry, returns]

    all_rows.append(new_row)


data = pd.DataFrame(all_rows, columns=["ticker", "quarter", "date", "sentiment", "subjectivity", "pos_neg_ratio", "sector", "sub_industry", "returns"])

print(time.time() - t0)

data
# Out:
# 500.89223074913025
#       ticker quarter       date  sentiment  subjectivity  pos_neg_ratio  \
# 0          T      Q1 2019-04-24   0.178707      0.074716       1.435185
# 1          T      Q4 2018-01-31   0.477551      0.069346       2.828125
# 2          T      Q3 2016-10-24   0.259434      0.103063       1.700637
# 3          T      Q2 2015-07-23   0.531746      0.080925       3.271186
# 4          T      Q3 2015-10-22   0.494424      0.076182       2.955882
# 5          T      Q3 2014-10-22   0.317365      0.057586       1.929825
# 6          T      Q4 2015-01-27   0.257732      0.057687       1.694444
# 7          T      Q3 2013-10-23   0.366516      0.072034       2.157143
# 8          T      Q4 2014-01-28   0.298701      0.068182       1.851852
# 9          T      Q2 2013-07-23   0.333333      0.065651       2.000000
# 10         T      Q1 2014-04-22   0.513274      0.072622       3.109091
# 11         T      Q2 2014-07-23   0.443946      0.069255       2.596774
# 12         T      Q1 2015-04-22   0.440678      0.067065       2.575758
# 13         T      Q4 2016-01-27   0.345455      0.075946       2.055556
# 14         T      Q1 2016-04-26   0.496063      0.082201       2.968750
# 15         T      Q2 2016-07-21   0.555556      0.071469       3.500000
# 16         T      Q1 2017-04-26   0.221757      0.063345       1.569892
# 17         T      Q2 2017-07-25   0.367187      0.073059       2.160494
# 18         T      Q1 2018-04-25   0.506726      0.065358       3.054545
# 19         T      Q2 2018-07-25   0.263736      0.075992       1.716418
# 20         T      Q3 2018-10-24   0.339286      0.065844       2.027027
# 21         T      Q4 2020-01-29   0.409253      0.077689       2.385542
# 22         T      Q3 2019-10-28   0.407115      0.066109       2.373333
# 23         T      Q2 2019-07-24   0.170732      0.067746       1.411765
# 24         T      Q1 2013-04-23   0.234043      0.076873       1.611111
# 25         T      Q4 2013-01-24   0.311005      0.066645       1.902778
# 26         T      Q4 2012-01-26   0.280374      0.061213       1.779221
# 27         T      Q1 2012-04-24   0.489583      0.061088       2.918367
# 28         T      Q2 2012-07-24   0.377551      0.070402       2.213115
# 29       PHM      Q4 2012-02-02   0.171233      0.081405       1.413223
# ...      ...     ...        ...        ...           ...            ...
# 11942    AOS      Q2 2019-07-30  -0.253012      0.079578       0.596154
# 11943    AOS      Q3 2019-10-29  -0.071429      0.066890       0.866667
# 11944    AOS      Q4 2020-01-28  -0.106977      0.081998       0.806723
# 11945    WFC      Q4 2015-01-15   0.092715      0.073479       1.204380
# 11946    WFC      Q1 2015-04-14   0.241379      0.066820       1.636364
# 11947    WFC      Q2 2015-07-14   0.096591      0.076688       1.213836
# 11948    WFC      Q3 2015-10-14   0.142857      0.072367       1.333333
# 11949    WFC      Q1 2016-04-14  -0.075581      0.073693       0.859459
# 11950    WFC      Q4 2012-01-17  -0.029412      0.086713       0.942857
# 11951    WFC      Q1 2012-04-13  -0.027356      0.081557       0.946746
# 11952    WFC      Q2 2012-07-13   0.055762      0.084326       1.118110
# 11953    WFC      Q3 2012-10-12  -0.071856      0.075361       0.865922
# 11954    WFC      Q4 2013-01-11  -0.066975      0.081223       0.874459
# 11955    WFC      Q1 2013-04-12   0.057357      0.092163       1.121693
# 11956    WFC      Q2 2013-07-12   0.068182      0.087754       1.146341
# 11957    WFC      Q4 2014-01-14   0.000000      0.088984       1.000000
# 11958    WFC      Q1 2014-04-11   0.083969      0.087959       1.183333
# 11959    WFC      Q3 2016-10-14  -0.170984      0.076285       0.707965
# 11960    WFC      Q4 2017-01-13  -0.031414      0.085439       0.939086
# 11961    WFC      Q3 2017-10-13  -0.089059      0.076998       0.836449
# 11962    WFC      Q4 2018-01-12   0.078788      0.080058       1.171053
# 11963    WFC      Q1 2018-04-13  -0.140401      0.080694       0.753769
# 11964    WFC      Q2 2018-07-13  -0.203252      0.080974       0.662162
# 11965    WFC      Q4 2019-01-15  -0.090395      0.074936       0.834197
# 11966    WFC      Q1 2019-04-12   0.004566      0.079942       1.009174
# 11967    WFC      Q2 2019-07-16  -0.028571      0.074574       0.944444
# 11968    WFC      Q3 2019-10-15  -0.067114      0.077082       0.874214
# 11969    WFC      Q4 2020-01-14   0.147826      0.078391       1.346939
# 11970    WFC      Q2 2014-07-11  -0.045714      0.077864       0.912568
# 11971    WFC      Q3 2014-10-14   0.038961      0.074306       1.081081
#
#                                                   sector  \
# 0      399    Telecommunication Services
# Name: GICS S...
# 1      399    Telecommunication Services
# Name: GICS S...
# 2      399    Telecommunication Services
# Name: GICS S...
# 3      399    Telecommunication Services
# Name: GICS S...
# 4      399    Telecommunication Services
# Name: GICS S...
# 5      399    Telecommunication Services
# Name: GICS S...
# 6      399    Telecommunication Services
# Name: GICS S...
# 7      399    Telecommunication Services
# Name: GICS S...
# 8      399    Telecommunication Services
# Name: GICS S...
# 9      399    Telecommunication Services
# Name: GICS S...
# 10     399    Telecommunication Services
# Name: GICS S...
# 11     399    Telecommunication Services
# Name: GICS S...
# 12     399    Telecommunication Services
# Name: GICS S...
# 13     399    Telecommunication Services
# Name: GICS S...
# 14     399    Telecommunication Services
# Name: GICS S...
# 15     399    Telecommunication Services
# Name: GICS S...
# 16     399    Telecommunication Services
# Name: GICS S...
# 17     399    Telecommunication Services
# Name: GICS S...
# 18     399    Telecommunication Services
# Name: GICS S...
# 19     399    Telecommunication Services
# Name: GICS S...
# 20     399    Telecommunication Services
# Name: GICS S...
# 21     399    Telecommunication Services
# Name: GICS S...
# 22     399    Telecommunication Services
# Name: GICS S...
# 23     399    Telecommunication Services
# Name: GICS S...
# 24     399    Telecommunication Services
# Name: GICS S...
# 25     399    Telecommunication Services
# Name: GICS S...
# 26     399    Telecommunication Services
# Name: GICS S...
# 27     399    Telecommunication Services
# Name: GICS S...
# 28     399    Telecommunication Services
# Name: GICS S...
# 29     340    Consumer Discretionary
# Name: GICS Secto...
# ...                                                  ...
# 11942  42    Industrials
# Name: GICS Sector, dtype: ob...
# 11943  42    Industrials
# Name: GICS Sector, dtype: ob...
# 11944  42    Industrials
# Name: GICS Sector, dtype: ob...
# 11945  442    Financials
# Name: GICS Sector, dtype: ob...
# 11946  442    Financials
# Name: GICS Sector, dtype: ob...
# 11947  442    Financials
# Name: GICS Sector, dtype: ob...
# 11948  442    Financials
# Name: GICS Sector, dtype: ob...
# 11949  442    Financials
# Name: GICS Sector, dtype: ob...
# 11950  442    Financials
# Name: GICS Sector, dtype: ob...
# 11951  442    Financials
# Name: GICS Sector, dtype: ob...
# 11952  442    Financials
# Name: GICS Sector, dtype: ob...
# 11953  442    Financials
# Name: GICS Sector, dtype: ob...
# 11954  442    Financials
# Name: GICS Sector, dtype: ob...
# 11955  442    Financials
# Name: GICS Sector, dtype: ob...
# 11956  442    Financials
# Name: GICS Sector, dtype: ob...
# 11957  442    Financials
# Name: GICS Sector, dtype: ob...
# 11958  442    Financials
# Name: GICS Sector, dtype: ob...
# 11959  442    Financials
# Name: GICS Sector, dtype: ob...
# 11960  442    Financials
# Name: GICS Sector, dtype: ob...
# 11961  442    Financials
# Name: GICS Sector, dtype: ob...
# 11962  442    Financials
# Name: GICS Sector, dtype: ob...
# 11963  442    Financials
# Name: GICS Sector, dtype: ob...
# 11964  442    Financials
# Name: GICS Sector, dtype: ob...
# 11965  442    Financials
# Name: GICS Sector, dtype: ob...
# 11966  442    Financials
# Name: GICS Sector, dtype: ob...
# 11967  442    Financials
# Name: GICS Sector, dtype: ob...
# 11968  442    Financials
# Name: GICS Sector, dtype: ob...
# 11969  442    Financials
# Name: GICS Sector, dtype: ob...
# 11970  442    Financials
# Name: GICS Sector, dtype: ob...
# 11971  442    Financials
# Name: GICS Sector, dtype: ob...
#
#                                             sub_industry   returns
# 0      399    Integrated Telecommunication Services
# N... -0.014615
# 1      399    Integrated Telecommunication Services
# N...  0.045661
# 2      399    Integrated Telecommunication Services
# N... -0.004341
# 3      399    Integrated Telecommunication Services
# N...  0.010610
# 4      399    Integrated Telecommunication Services
# N... -0.006478
# 5      399    Integrated Telecommunication Services
# N... -0.024348
# 6      399    Integrated Telecommunication Services
# N... -0.003962
# 7      399    Integrated Telecommunication Services
# N... -0.018424
# 8      399    Integrated Telecommunication Services
# N... -0.011573
# 9      399    Integrated Telecommunication Services
# N... -0.011449
# 10     399    Integrated Telecommunication Services
# N... -0.037752
# 11     399    Integrated Telecommunication Services
# N... -0.010591
# 12     399    Integrated Telecommunication Services
# N...  0.041692
# 13     399    Integrated Telecommunication Services
# N...  0.001409
# 14     399    Integrated Telecommunication Services
# N...  0.016540
# 15     399    Integrated Telecommunication Services
# N...  0.013876
# 16     399    Integrated Telecommunication Services
# N... -0.013106
# 17     399    Integrated Telecommunication Services
# N...  0.049972
# 18     399    Integrated Telecommunication Services
# N... -0.059659
# 19     399    Integrated Telecommunication Services
# N...  0.003306
# 20     399    Integrated Telecommunication Services
# N... -0.012517
# 21     399    Integrated Telecommunication Services
# N...  0.010256
# 22     399    Integrated Telecommunication Services
# N... -0.011172
# 23     399    Integrated Telecommunication Services
# N...  0.017148
# 24     399    Integrated Telecommunication Services
# N... -0.050256
# 25     399    Integrated Telecommunication Services
# N...  0.008000
# 26     399    Integrated Telecommunication Services
# N... -0.009847
# 27     399    Integrated Telecommunication Services
# N...  0.000631
# 28     399    Integrated Telecommunication Services
# N...  0.020214
# 29     340    Homebuilding
# Name: GICS Sub Industry, d...  0.070968
# ...                                                  ...       ...
# 11942  42    Building Products
# Name: GICS Sub Industr...  0.003533
# 11943  42    Building Products
# Name: GICS Sub Industr...  0.023360
# 11944  42    Building Products
# Name: GICS Sub Industr... -0.025940
# 11945  442    Diversified Banks
# Name: GICS Sub Indust...  0.018139
# 11946  442    Diversified Banks
# Name: GICS Sub Indust...  0.011441
# 11947  442    Diversified Banks
# Name: GICS Sub Indust...  0.009258
# 11948  442    Diversified Banks
# Name: GICS Sub Indust...  0.023107
# 11949  442    Diversified Banks
# Name: GICS Sub Indust... -0.011068
# 11950  442    Diversified Banks
# Name: GICS Sub Indust...  0.013745
# 11951  442    Diversified Banks
# Name: GICS Sub Indust...  0.009440
# 11952  442    Diversified Banks
# Name: GICS Sub Indust...  0.003244
# 11953  442    Diversified Banks
# Name: GICS Sub Indust... -0.010219
# 11954  442    Diversified Banks
# Name: GICS Sub Indust... -0.009402
# 11955  442    Diversified Banks
# Name: GICS Sub Indust... -0.017200
# 11956  442    Diversified Banks
# Name: GICS Sub Indust...  0.016889
# 11957  442    Diversified Banks
# Name: GICS Sub Indust...  0.017767
# 11958  442    Diversified Banks
# Name: GICS Sub Indust...  0.000624
# 11959  442    Diversified Banks
# Name: GICS Sub Indust... -0.004697
# 11960  442    Diversified Banks
# Name: GICS Sub Indust... -0.027662
# 11961  442    Diversified Banks
# Name: GICS Sub Indust...  0.002049
# 11962  442    Diversified Banks
# Name: GICS Sub Indust... -0.000799
# 11963  442    Diversified Banks
# Name: GICS Sub Indust... -0.001769
# 11964  442    Diversified Banks
# Name: GICS Sub Indust...  0.029444
# 11965  442    Diversified Banks
# Name: GICS Sub Indust...  0.026642
# 11966  442    Diversified Banks
# Name: GICS Sub Indust...  0.006023
# 11967  442    Diversified Banks
# Name: GICS Sub Indust... -0.001987
# 11968  442    Diversified Banks
# Name: GICS Sub Indust... -0.010377
# 11969  442    Diversified Banks
# Name: GICS Sub Indust... -0.019878
# 11970  442    Diversified Banks
# Name: GICS Sub Indust... -0.003496
# 11971  442    Diversified Banks
# Name: GICS Sub Indust... -0.020070
#
# [11972 rows x 9 columns]

# %%
with open("all_data.p", "wb") as f:
    pickle.dump(data, f)
